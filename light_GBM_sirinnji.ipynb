# %% [markdown]
# <a href="https://colab.research.google.com/github/dennkitotaichi/CE_PLUS/blob/patch-1/light_GBM_sirinnji.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dec8b6d6-1878-410e-8fdf-e0d1669d3279" name="files[]" multiple disabled />
#      <output id="result-dec8b6d6-1878-410e-8fdf-e0d1669d3279">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testTotal2019.csv to testTotal2019.csv

# %%
import pandas as pd

dt = pd.read_csv('testTotal2019.csv')
print(dt)
df = pd.DataFrame(dt)
print(df)
print(df.columns)
print(df.columns[[0]])
print(df.drop(df.columns[[0]], axis=1))
dtt=df.drop(df.columns[[0]], axis=1)
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns
sns.set()
import collections
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from keras.models import Sequential
from keras import layers
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier
from keras import regularizers
import xgboost as xgb
import warnings
warnings.filterwarnings('ignore')
sns.boxplot(x="sirinnji", y="total", data=dtt)

import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn import preprocessing
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import r2_score

import random

from pandas.plotting import scatter_matrix
# Out:
#      Unnamed: 0  ...  Average cloud volume (10 pct)
# 0      2016/9/1  ...                            4.3
# 1      2016/9/2  ...                            9.5
# 2      2016/9/3  ...                           10.0
# 3      2016/9/4  ...                           10.0
# 4      2016/9/5  ...                            8.3
# ...         ...  ...                            ...
# 1090  2019/8/27  ...                            3.8
# 1091  2019/8/28  ...                           10.0
# 1092  2019/8/29  ...                           10.0
# 1093  2019/8/30  ...                            7.8
# 1094  2019/8/31  ...                            6.3
#
# [1095 rows x 24 columns]
#      Unnamed: 0  ...  Average cloud volume (10 pct)
# 0      2016/9/1  ...                            4.3
# 1      2016/9/2  ...                            9.5
# 2      2016/9/3  ...                           10.0
# 3      2016/9/4  ...                           10.0
# 4      2016/9/5  ...                            8.3
# ...         ...  ...                            ...
# 1090  2019/8/27  ...                            3.8
# 1091  2019/8/28  ...                           10.0
# 1092  2019/8/29  ...                           10.0
# 1093  2019/8/30  ...                            7.8
# 1094  2019/8/31  ...                            6.3
#
# [1095 rows x 24 columns]
# Index(['Unnamed: 0', 'total', 'man', 'woman', 'kokyuuki', 'sinndennzu',
#        'sirinnji', 'kaitouOP', 'kaikyouOP', 'kaifukuOP', 'honenoOP',
#        'fukukuukyou', 'elseOP', 'Average temperature (C)',
#        'Lowest temperature ?', 'Maximum temperature ?',
#        'Total precipitation (mm)', 'Daylight Hours (Hours)',
#        'Deepest Snow (cm)', 'Total snowfall (cm)', 'Total snowfall (cm).1',
#        'Minimum relative humidity (%)', 'Average local pressure (hPa)',
#        'Average cloud volume (10 pct)'],
#       dtype='object')
# Index(['Unnamed: 0'], dtype='object')
#       total  man  ...  Average local pressure (hPa)  Average cloud volume (10 pct)
# 0       165   90  ...                        1006.6                            4.3
# 1       161   87  ...                        1012.7                            9.5
# 2       156   80  ...                        1015.2                           10.0
# 3       156   78  ...                        1015.4                           10.0
# 4       171   84  ...                        1010.8                            8.3
# ...     ...  ...  ...                           ...                            ...
# 1090    113   57  ...                        1012.5                            3.8
# 1091    119   60  ...                        1007.1                           10.0
# 1092    123   64  ...                        1002.2                           10.0
# 1093    122   63  ...                        1004.6                            7.8
# 1094    107   54  ...                        1005.4                            6.3
#
# [1095 rows x 23 columns]
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()


# 説明変数に "kokyuuki(kokyuukiスコア以外すべて)" を利用
wine_except_quality = dtt.drop('sirinnji', axis=1)
X = wine_except_quality.values
 
# 目的変数に "sirinnji" を利用
Y = dtt['sirinnji'].values
 
# 予測モデルを作成
clf.fit(X, Y)
 
# 偏回帰係数
print(pd.DataFrame({"Name":wine_except_quality.columns,
                    "Coefficients":clf.coef_}).sort_values(by='Coefficients') )
 
# 切片 (誤差)
print(clf.intercept_)


print("------------------------------------------------------------")

 
# データフレームの各列を正規化
wine2 = dtt.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)))
wine2.head()
 
wine2.hist(bins=30,rwidth=0.2 ,figsize=(6,6), color = 'orange') ;
plt.tight_layout()
plt.show()

sirinnji = df['total'].values
sirinnji2 = preprocessing.minmax_scale(sirinnji)
print(sirinnji2)

kaifukuOP = df['woman'].values
kaifukuOP2 = preprocessing.minmax_scale(kaifukuOP)
print(kaifukuOP2)

youso3 = df['man'].values
youso3seikika = preprocessing.minmax_scale(kaifukuOP)
print(youso3seikika)

sika=np.array([sirinnji2,kaifukuOP2,youso3])
si=sika.T
X=si

print("X.shape")
print(X.shape)

targetk = df['sirinnji'].values
siY=targetk.T
Y=siY


print(Y.shape)

# 訓練用のデータと、テスト用のデータに分ける
N_train = int(len(df) * 0.70)
N_test = len(df) - N_train
X_train, X_test, y_train, y_test = \
    train_test_split(X, Y, test_size=N_test, shuffle = False) 

from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression


from sklearn import svm  
from sklearn.metrics import accuracy_score
import lightgbm as lgb
from sklearn.metrics import r2_score


lgb_params = {
   'reg_lambda': 0.0,
   'reg_alpha': 0.0,
   'num_leaves': 600,
   'n_estimators': 30000,
   'min_data_leaf': 50,
   'learning_rate': 0.025,
   'bagging_fraction': 0.8,
            }

lgb_model = lgb.LGBMRegressor(**lgb_params)

# 上記のパラメータでモデルを学習する

# 学習用のデータと結果を学習する,fit(X_train:学習データ, learn_label:答えデータ)
lgb_model.fit(X_train, y_train)
# テストデータによる予測,lightgbmでX_testを予想：predictした値をY_predとする
Y_pred = lgb_model.predict(X_test)


lgb.LGBMClassifier()
#「LGBMClassifier」のクラスを呼び出して、ハイパーパラメータの初期値を確認

# テストデータによる予測,lightgbmでX_testを予想：predictした値をY_predとする
Y_pred = lgb_model.predict(X_test)

# テスト結果を評価する,accuracy_score()
print("予測対象：", y_test, ", 予測結果→", Y_pred)

from sklearn.metrics import mean_absolute_error
print("平均絶対誤差 (MAE, Mean Absolute Error") 
print(mean_absolute_error(y_test, Y_pred))

## RMSEの計算
print("二乗平均平方根誤差（RMSE） : %.3f" %  
       np.sqrt(mean_squared_error(y_test,Y_pred)))

## test_r2_score計算
test_r2_score = r2_score(y_test,Y_pred)
print("test_r2_score")
print(test_r2_score)

## 予測結果をプロット
pre_date = df.index[-len(y_test):].values
plt.title(" yosokuti")
plt.plot(pre_date, y_test, 'b', alpha=0.6, marker='.', label="実際 jissaino  ", linewidth=1)
plt.plot(pre_date, Y_pred, 'r', alpha=0.6, marker='.', label="予測値 yosokuti", linewidth=1)
plt.xticks(rotation=70)
plt.legend()
plt.grid(True)
plt.show()


from sklearn.metrics import classification_report

 #Grid searcharn.grid_search import GridSearchCV
from sklearn.model_selection import GridSearchCV
 # use a full grid over all parameters

def lgb_params2():
   ret = {
        # 0.0以上1.0以下を3分割したarrayを作る
   #'reg_lambda':[0,0.1,1],
   #'reg_alpha':[0,0.1,1],
   'num_leaves':[10,20,31],
   'max_depth':[-1,-3],
   'max_bin':[255,500],
   'n_estimators':[10,50,100],
   'min_data_leaf': [10,20,30],
   'learning_rate': [0.001,0.01],
   'num_iterations': [150,300],
   'bagging_fraction':[1.0,0.9],
   }
   return ret

gscv = GridSearchCV(lgb.LGBMRegressor(), lgb_params2(), cv=4, verbose=2)
gscv.fit(X_train, y_train)

gs_result = pd.DataFrame.from_dict(gscv.cv_results_)
print('gs_result')
print(gs_result)
# Out:
#                              Name  Coefficients
# 5                        kaitouOP     -0.487603
# 9                     fukukuukyou     -0.154450
# 1                             man     -0.153783
# 2                           woman     -0.108276
# 15         Daylight Hours (Hours)     -0.107434
# 21  Average cloud volume (10 pct)     -0.070116
# 17            Total snowfall (cm)     -0.020358
# 8                        honenoOP     -0.012234
# 19  Minimum relative humidity (%)     -0.010244
# 14       Total precipitation (mm)     -0.010065
# 11        Average temperature (C)     -0.008416
# 13          Maximum temperature ?     -0.006994
# 7                       kaifukuOP     -0.006229
# 16              Deepest Snow (cm)      0.003939
# 20   Average local pressure (hPa)      0.026930
# 12           Lowest temperature ?      0.044669
# 4                      sinndennzu      0.069103
# 10                         elseOP      0.085186
# 0                           total      0.169722
# 18          Total snowfall (cm).1      0.279653
# 3                        kokyuuki      0.405558
# 6                       kaikyouOP      1.837780
# -30.09838163019573
# ------------------------------------------------------------
# [0.6484375 0.6171875 0.578125  ... 0.3203125 0.3125    0.1953125]
# [0.56756757 0.55405405 0.58108108 ... 0.35135135 0.35135135 0.27027027]
# [0.56756757 0.55405405 0.58108108 ... 0.35135135 0.35135135 0.27027027]
# X.shape
# (1095, 3)
# (1095,)
# 予測対象： [ 7  6 10  9  8  9  9  9  8 12  9 11  8  6  6  8 11  9  7  8  7  8  9 12
#  13 10 13  9  9 11 10 10 12 11  8  9  9  9  9 10  8  8  9 10  7  6  5  5
#   5  5  8  8  6  7  6  6  5  6 10  8  8  8  7  8  8  7 11  6  5  5  5  5
#   6  7  6  6  3  3  4  4  7  5  5  4  5  5  6  8  6  5  3  3  3  4  3  5
#   5  3  4  3  5  3  3  3  3  4  4  4  4  3  3  4  4  4  3  3  2  2  2  2
#   2  2  3  4 11  9  6  6  8  6  6  6  6  5  8  8  9  7 10  5  7 11 11  6
#   7  7  5  6  5  6 11  7  9  6  6  6  6  7  6  5  5  4  4  5  3  3  3  2
#   3  5  2  4  5  2  3  3  3  3  5  3  2  1  1  2  4  5  5  7  4  3  4  2
#   3  2  3  1  2  2  3  1  3  4  3  3  2  3  3  3  3  3  3  3  4  5  4  2
#   1  2  4  5  5  5  5  2  2  2  1  1  1  3  4  5  5  5  4  5  4  3  3  5
#   8  5  5  5  6  4  7  5  8  9  8  5  5  5  5  6  2  3  2  1  2  2  4  3
#   3  3  2  3  1  3  5  4  2  4  4  3  5  2  1  0  0  0  1  2  1  1  2  2
#   1  3  4  5  7  3  3  8  3  4  3  5  3  3  4  2  3  3  5  2  1  1  2  0
#   2  2  2  2  3  5  4  5  7  3  4  4  3  3  5  5  5] , 予測結果→ [ 4.13191612  5.6245683   8.15982224  2.00954283  8.63045337  4.29049393
#   6.41402538  5.38546835  6.10053883  8.98484076  8.98484076  8.84329743
#   5.79747165  4.84590051  3.21164626  3.34532154  8.94806994  7.67441682
#   8.94806994  7.90412612  7.99216282  7.9641408   7.01846457  1.02168629
#   2.07395866 10.15704212  4.32236972  2.99053988  3.44832227  6.52419128
#   5.36931836  6.04702306  7.00920693  6.93881133  5.39994259  8.28036001
#   3.03392317  8.97704544  8.024309    6.99818592  6.94909326  5.99445619
#   4.68524294  6.38171106  8.46784223  5.00448831  7.33615073  2.57237651
#   4.65092612  4.99305916  3.50900218  4.99883568  8.67298266  6.01489172
#   6.92520937  3.34234408  2.31879229  7.06950209  6.0026324   6.52419128
#  13.9146579   2.00867695  7.14295049  2.70741159  1.08044072  3.99995402
#   5.18191977  6.38171106  0.84830262  2.1544959   3.17681484  8.85098539

# 平均絶対誤差 (MAE, Mean Absolute Error
# 2.4652765233311573
# 二乗平均平方根誤差（RMSE） : 3.204
# test_r2_score
# -0.40138571124666544
# Fitting 4 folds for each of 864 candidates, totalling 3456 fits
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=10, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=1.0, learning_rate=0.001, max_bin=255, max_depth=-1, min_data_leaf=20, n_estimators=100, num_iterations=300, num_leaves=10
# ...
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=10, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=10, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=50, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=20, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=150, num_leaves=31, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.0s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=10, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=20, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# [CV] bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31
# [CV]  bagging_fraction=0.9, learning_rate=0.01, max_bin=500, max_depth=-3, min_data_leaf=30, n_estimators=100, num_iterations=300, num_leaves=31, total=   0.1s
# gs_result
#      mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0         0.029419      0.006997  ...        0.549529              649
# 1         0.042634      0.003866  ...        0.548434              793
# 2         0.044326      0.008652  ...        0.548087              721
# 3         0.047443      0.003106  ...        0.524291              433
# 4         0.075909      0.003959  ...        0.526394              577
# ..             ...           ...  ...             ...              ...
# 859       0.039661      0.003153  ...        0.477056               73
# 860       0.043746      0.003470  ...        0.473627                1
# 861       0.050049      0.002633  ...        0.483841              217
# 862       0.080946      0.006726  ...        0.493140              289
# 863       0.081292      0.002380  ...        0.500769              361
#
# [864 rows x 20 columns]
# [Parallel(n_jobs=1)]: Done 3456 out of 3456 | elapsed:  3.2min finished

# %%
gs_result = pd.DataFrame.from_dict(gscv.cv_results_)
print('gs_result')
print(gs_result)

print(gs_result.mean())

gs_result.to_csv('gs_result2.csv')
  # 最高性能のモデルを取得し、テストデータを分類
best = gscv.best_estimator_
pred = best.predict(X_test)

  # 混同行列を出力
print(pred)

# テスト結果を評価する,accuracy_score()
print("予測対象：", y_test, ", 予測結果→", pred)

from sklearn.metrics import mean_absolute_error
print("平均絶対誤差 (MAE, Mean Absolute Error") 
print(mean_absolute_error(y_test, pred))

## RMSEの計算
print("二乗平均平方根誤差（RMSE） : %.3f" %  
       np.sqrt(mean_squared_error(y_test,pred)))

## test_r2_score計算
test_r2_score = r2_score(y_test,pred)
print("test_r2_score")
print(test_r2_score)

## 予測結果をプロット
pre_date = df.index[-len(y_test):].values
plt.title(" yosokuti")
plt.plot(pre_date, y_test, 'b', alpha=0.6, marker='.', label="実際 jissaino  ", linewidth=1)
plt.plot(pre_date, pred, 'r', alpha=0.6, marker='.', label="予測値 yosokuti", linewidth=1)
plt.xticks(rotation=70)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# gs_result
#      mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0         0.029419      0.006997  ...        0.549529              649
# 1         0.042634      0.003866  ...        0.548434              793
# 2         0.044326      0.008652  ...        0.548087              721
# 3         0.047443      0.003106  ...        0.524291              433
# 4         0.075909      0.003959  ...        0.526394              577
# ..             ...           ...  ...             ...              ...
# 859       0.039661      0.003153  ...        0.477056               73
# 860       0.043746      0.003470  ...        0.473627                1
# 861       0.050049      0.002633  ...        0.483841              217
# 862       0.080946      0.006726  ...        0.493140              289
# 863       0.081292      0.002380  ...        0.500769              361
#
# [864 rows x 20 columns]
# mean_fit_time               0.053088
# std_fit_time                0.003086
# mean_score_time             0.002054
# std_score_time              0.000211
# param_bagging_fraction      0.950000
# param_learning_rate         0.005500
# param_max_bin             377.500000
# param_max_depth            -2.000000
# param_min_data_leaf        20.000000
# param_n_estimators         53.333333
# param_num_iterations      225.000000
# param_num_leaves           20.333333
# split0_test_score          -0.048340
# split1_test_score           0.080149
# split2_test_score          -1.181873
# split3_test_score          -0.263029
# mean_test_score            -0.353273
# std_test_score              0.509937
# rank_test_score           397.000000
# dtype: float64
# [5.31246218 5.6826321  5.89446367 6.33352327 7.33016962 5.69958608
#  3.81431973 3.78182966 3.78182966 3.78182966 4.35478422 4.90241107
#  5.39549741 5.73291853 4.35478422 4.35478422 5.39549741 5.62053156
#  5.19497157 6.19092143 4.46512164 3.78182966 3.78182966 3.78182966
#  4.40193559 4.9282214  5.47124449 5.40446595 3.82500613 3.78182966
#  3.85749619 5.16215441 5.31308427 5.14877984 5.01167452 3.82500613
#  3.78182966 3.82500613 4.27087306 5.17541526 5.17112745 5.17112745
#  3.82500613 3.82500613 4.27087306 4.27087306 4.0158743  4.0158743
#  3.78182966 3.78182966 3.78182966 3.78182966 3.82500613 3.82500613
#  4.0158743  3.82500613 3.78182966 3.78182966 3.78182966 3.81431973
#  3.78182966 3.85749619 3.82500613 3.78182966 3.78182966 3.78182966
#  3.82500613 3.82500613 4.42592541 3.89216708 3.78182966]
# 予測対象： [ 7  6 10  9  8  9  9  9  8 12  9 11  8  6  6  8 11  9  7  8  7  8  9 12
#  13 10 13  9  9 11 10 10 12 11  8  9  9  9  9 10  8  8  9 10  7  6  5  5
#   5  5  8  8  6  7  6  6  5  6 10  8  8  8  7  8  8  7 11  6  5  5  5  5
#   6  7  6  6  3  3  4  4  7  5  5  4  5  5  6  8  6  5  3  3  3  4  3  5
#   5  3  4  3  5  3  3  3  3  4  4  4  4  3  3  4  4  4  3  3  2  2  2  2
#   2  2  3  4 11  9  6  6  8  6  6  6  6  5  8  8  9  7 10  5  7 11 11  6
#   7  7  5  6  5  6 11  7  9  6  6  6  6  7  6  5  5  4  4  5  3  3  3  2
#   3  5  2  4  5  2  3  3  3  3  5  3  2  1  1  2  4  5  5  7  4  3  4  2
#   3  2  3  1  2  2  3  1  3  4  3  3  2  3  3  3  3  3  3  3  4  5  4  2
#   1  2  4  5  5  5  5  2  2  2  1  1  1  3  4  5  5  5  4  5  4  3  3  5
#   8  5  5  5  6  4  7  5  8  9  8  5  5  5  5  6  2  3  2  1  2  2  4  3
#   3  3  2  3  1  3  5  4  2  4  4  3  5  2  1  0  0  0  1  2  1  1  2  2
#   1  3  4  5  7  3  3  8  3  4  3  5  3  3  4  2  3  3  5  2  1  1  2  0
#   2  2  2  2  3  5  4  5  7  3  4  4  3  3  5  5  5] , 予測結果→ [5.31246218 5.6826321  5.89446367 6.33352327 7.33016962 5.69958608
#  5.33974194 5.27258099 6.20047216 7.52549284 7.52549284 7.76179537
#  6.23001829 5.19497157 4.78400584 5.9099116  7.25271366 7.30161248
#  7.25271366 7.22064734 5.48278197 5.39549741 4.92718661 4.90723937
#  5.34000772 5.46840344 5.38437319 3.82500613 3.82500613 6.09650839
#  4.92718661 6.03760046 5.9886283  5.90338324 6.19092143 5.35563865
#  5.63522958 6.3526846  7.264924   5.43071921 5.92366947 5.8184806
#  5.39549741 5.44790922 6.25765655 6.32565919 7.05227292 4.72288503
#  5.38437319 5.14877984 5.49094915 6.2141554  6.92375239 6.25477701
#  6.37550222 5.19860954 3.85749619 6.15605487 6.34329699 6.09650839
#  6.07276672 4.84323893 5.35563865 5.76566733 4.43550417 5.36097118
#  5.82251346 5.44790922 5.21786335 5.38437319 4.35478422 6.19092143
#  4.42454856 4.76727668 6.11081284 5.93945773 5.6826321  3.78182966
#  4.35478422 5.73291853 5.78879047 5.78168938 4.35478422 3.78182966
